# %%
#Importing packages 
import numpy as np
import pandas as pd
import anndata as ad
from scipy.sparse import csr_matrix

# %%
#Data loading

version1 = ad.read_h5ad("./v1_raw.h5ad")
version2 = ad.read_h5ad("./v2_raw.h5ad")

# %%
version1
# Out:
# AnnData object with n_obs × n_vars = 486134 × 33538
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45'
#     uns: 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
version1.obs
# Out:
#                                     NRP age_group     cell_source  \
# AAACCCAAGAACGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCAAACAT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCTACTGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAGTACCGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCATCAAACCCA-1-H0015_apex        No     50-55  Harvard-Nuclei
# ...                                 ...       ...             ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCCTACCAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGACGCTG-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
#
#                                                     cell_type donor  gender  \
# AAACCCAAGAACGCGT-1-H0015_apex             Smooth_muscle_cells    H5  Female
# AAACCCAAGCAAACAT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAAGCTACTGT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAGTACCGCGT-1-H0015_apex                       Pericytes    H5  Female
# AAACCCATCAAACCCA-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# ...                                                       ...   ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCCTACCAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGACGCTG-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862                Endothelial   D11  Female
#
#                                     n_counts  n_genes  percent_mito  \
# AAACCCAAGAACGCGT-1-H0015_apex          688.0      480      0.004360
# AAACCCAAGCAAACAT-1-H0015_apex         3216.0     1365      0.000933
# AAACCCAAGCTACTGT-1-H0015_apex         3182.0     1521      0.000943
# AAACCCAGTACCGCGT-1-H0015_apex         1202.0      726      0.000832
# AAACCCATCAAACCCA-1-H0015_apex         3804.0     1584      0.000263
# ...                                      ...      ...           ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862    1619.0      904      0.087708
# TTTGTTGTCCTACCAC-1-HCAHeart8102862    1186.0      692      0.126476
# TTTGTTGTCGACGCTG-1-HCAHeart8102862    1672.0      847      0.145335
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862    4676.0     1925      0.163388
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862    3144.0     1422      0.097010
#
#                                     percent_ribo region           sample  \
# AAACCCAAGAACGCGT-1-H0015_apex           0.002907     AX       H0015_apex
# AAACCCAAGCAAACAT-1-H0015_apex           0.001244     AX       H0015_apex
# AAACCCAAGCTACTGT-1-H0015_apex           0.002200     AX       H0015_apex
# AAACCCAGTACCGCGT-1-H0015_apex           0.000000     AX       H0015_apex
# AAACCCATCAAACCCA-1-H0015_apex           0.001314     AX       H0015_apex
# ...                                          ...    ...              ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862      0.024707     AX  HCAHeart8102862
# TTTGTTGTCCTACCAC-1-HCAHeart8102862      0.015177     AX  HCAHeart8102862
# TTTGTTGTCGACGCTG-1-HCAHeart8102862      0.044258     AX  HCAHeart8102862
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862      0.044482     AX  HCAHeart8102862
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862      0.026081     AX  HCAHeart8102862
#
#                                     scrublet_score  source type version  \
# AAACCCAAGAACGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCAAGCAAACAT-1-H0015_apex             0.147122  Nuclei  DBD      V3
# AAACCCAAGCTACTGT-1-H0015_apex             0.185751  Nuclei  DBD      V3
# AAACCCAGTACCGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCATCAAACCCA-1-H0015_apex             0.108062  Nuclei  DBD      V3
# ...                                            ...     ...  ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862        0.108062   CD45+  DCD      V3
# TTTGTTGTCCTACCAC-1-HCAHeart8102862        0.085546   CD45+  DCD      V3
# TTTGTTGTCGACGCTG-1-HCAHeart8102862        0.113475   CD45+  DCD      V3
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862        0.042770   CD45+  DCD      V3
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862        0.147122   CD45+  DCD      V3
#
#                                    cell_states Used
# AAACCCAAGAACGCGT-1-H0015_apex       SMC1_basic  Yes
# AAACCCAAGCAAACAT-1-H0015_apex             vCM1  Yes
# AAACCCAAGCTACTGT-1-H0015_apex             vCM1  Yes
# AAACCCAGTACCGCGT-1-H0015_apex        PC2_atria  Yes
# AAACCCATCAAACCCA-1-H0015_apex             vCM2  Yes
# ...                                        ...  ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCCTACCAC-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGACGCTG-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862     EC5_art  Yes
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  EC4_immune  Yes
#
# [486134 rows x 18 columns]

# %%
version2
# Out:
# AnnData object with n_obs × n_vars = 704296 × 32732
#     obs: 'sangerID', 'combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age', 'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'flushed', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_type', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'cell_state', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'n_counts', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     var: 'gene_name-new', 'gene_name_scRNA-0-original', 'gene_name_snRNA-1-original', 'gene_name_multiome-2-original'
#     uns: 'age_colors', 'cell_or_nuclei_colors', 'cell_state_colors', 'cell_type_colors', 'donor_colors', 'donor_type_colors', 'facility_colors', 'flushed_colors', 'gender_colors', 'kit_10x_colors', 'leiden', 'modality_colors', 'neighbors', 'original_or_new_colors', 'region_colors', 'region_finest_colors', 'scANVI_predictions_colors', 'umap'
#     obsm: 'X_scArches', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
version2.obs
# Out:
#                                                               sangerID  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                       HCAHeart7606896
# HCAHeart7606896_CGCTTCACATTTGCCC                       HCAHeart7606896
# HCAHeart7606896_GTTAAGCAGAGACTAT                       HCAHeart7606896
# HCAHeart7606896_TCGCGTTGTAAGAGGA                       HCAHeart7606896
# HCAHeart7606896_GCTGCGAGTGTTGGGA                       HCAHeart7606896
# ...                                                                ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...  HCAHeartST13180619
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...  HCAHeartST13180619
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...  HCAHeartST13180619
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...  HCAHeartST13180619
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...  HCAHeartST13180619
#
#                                                                                combinedID  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                                                       na
# HCAHeart7606896_CGCTTCACATTTGCCC                                                       na
# HCAHeart7606896_GTTAAGCAGAGACTAT                                                       na
# HCAHeart7606896_TCGCGTTGTAAGAGGA                                                       na
# HCAHeart7606896_GCTGCGAGTGTTGGGA                                                       na
# ...                                                                                   ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...  HCAHeartST13180619_HCAHeartST13177116
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...  HCAHeartST13180619_HCAHeartST13177116
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...  HCAHeartST13180619_HCAHeartST13177116
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...  HCAHeartST13180619_HCAHeartST13177116
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...  HCAHeartST13180619_HCAHeartST13177116
#
#                                                    donor donor_type region  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                      D1        DBD     AX
# HCAHeart7606896_CGCTTCACATTTGCCC                      D1        DBD     AX
# HCAHeart7606896_GTTAAGCAGAGACTAT                      D1        DBD     AX
# HCAHeart7606896_TCGCGTTGTAAGAGGA                      D1        DBD     AX
# HCAHeart7606896_GCTGCGAGTGTTGGGA                      D1        DBD     AX
# ...                                                  ...        ...    ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...   AH2        DCD    AVN
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...   AH2        DCD    AVN
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...   AH2        DCD    AVN
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...   AH2        DCD    AVN
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...   AH2        DCD    AVN
#
#                                                    region_finest    age  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                              AX  50-55
# HCAHeart7606896_CGCTTCACATTTGCCC                              AX  50-55
# HCAHeart7606896_GTTAAGCAGAGACTAT                              AX  50-55
# HCAHeart7606896_TCGCGTTGTAAGAGGA                              AX  50-55
# HCAHeart7606896_GCTGCGAGTGTTGGGA                              AX  50-55
# ...                                                          ...    ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...           AVN  40-45
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...           AVN  40-45
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...           AVN  40-45
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...           AVN  40-45
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...           AVN  40-45
#
#                                                     gender facility  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                    Female   Sanger
# HCAHeart7606896_CGCTTCACATTTGCCC                    Female   Sanger
# HCAHeart7606896_GTTAAGCAGAGACTAT                    Female   Sanger
# HCAHeart7606896_TCGCGTTGTAAGAGGA                    Female   Sanger
# HCAHeart7606896_GCTGCGAGTGTTGGGA                    Female   Sanger
# ...                                                    ...      ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...    Male   Sanger
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...    Male   Sanger
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...    Male   Sanger
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...    Male   Sanger
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...    Male   Sanger
#
#                                                    cell_or_nuclei  ...  \
# barcode                                                            ...
# HCAHeart7606896_GATGAGGCACGGCTAC                             Cell  ...
# HCAHeart7606896_CGCTTCACATTTGCCC                             Cell  ...
# HCAHeart7606896_GTTAAGCAGAGACTAT                             Cell  ...
# HCAHeart7606896_TCGCGTTGTAAGAGGA                             Cell  ...
# HCAHeart7606896_GCTGCGAGTGTTGGGA                             Cell  ...
# ...                                                           ...  ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...         Nuclei  ...
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...         Nuclei  ...
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...         Nuclei  ...
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...         Nuclei  ...
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...         Nuclei  ...
#
#                                                    latent_scale n_counts  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                            NaN      NaN
# HCAHeart7606896_CGCTTCACATTTGCCC                            NaN      NaN
# HCAHeart7606896_GTTAAGCAGAGACTAT                            NaN      NaN
# HCAHeart7606896_TCGCGTTGTAAGAGGA                            NaN      NaN
# HCAHeart7606896_GCTGCGAGTGTTGGGA                            NaN      NaN
# ...                                                         ...      ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...  4615.056641    506.0
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...  4723.684082    504.0
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...  4700.160156    501.0
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...  4439.463379    507.0
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...  4449.288086    504.0
#
#                                                    _scvi_batch  _scvi_labels  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                           NaN           NaN
# HCAHeart7606896_CGCTTCACATTTGCCC                           NaN           NaN
# HCAHeart7606896_GTTAAGCAGAGACTAT                           NaN           NaN
# HCAHeart7606896_TCGCGTTGTAAGAGGA                           NaN           NaN
# HCAHeart7606896_GCTGCGAGTGTTGGGA                           NaN           NaN
# ...                                                        ...           ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...         1.0           0.0
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...         1.0           0.0
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...         1.0           0.0
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...         1.0           0.0
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...         1.0           0.0
#
#                                                     clus20  doublet_cls  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                        No          nan
# HCAHeart7606896_CGCTTCACATTTGCCC                        No          nan
# HCAHeart7606896_GTTAAGCAGAGACTAT                        No          nan
# HCAHeart7606896_TCGCGTTGTAAGAGGA                        No          nan
# HCAHeart7606896_GCTGCGAGTGTTGGGA                        No          nan
# ...                                                    ...          ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...      No           No
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...      No           No
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...      No           No
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...      No           No
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...      No           No
#
#                                                     original_or_new  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                           original
# HCAHeart7606896_CGCTTCACATTTGCCC                           original
# HCAHeart7606896_GTTAAGCAGAGACTAT                           original
# HCAHeart7606896_TCGCGTTGTAAGAGGA                           original
# HCAHeart7606896_GCTGCGAGTGTTGGGA                           original
# ...                                                             ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...              new
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...              new
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...              new
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...              new
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...              new
#
#                                                                      batch  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                         D1_Cell_3prime-v2
# HCAHeart7606896_CGCTTCACATTTGCCC                         D1_Cell_3prime-v2
# HCAHeart7606896_GTTAAGCAGAGACTAT                         D1_Cell_3prime-v2
# HCAHeart7606896_TCGCGTTGTAAGAGGA                         D1_Cell_3prime-v2
# HCAHeart7606896_GCTGCGAGTGTTGGGA                         D1_Cell_3prime-v2
# ...                                                                    ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...  AH2_Nuclei_Multiome-v1
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...  AH2_Nuclei_Multiome-v1
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...  AH2_Nuclei_Multiome-v1
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...  AH2_Nuclei_Multiome-v1
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...  AH2_Nuclei_Multiome-v1
#
#                                                     scANVI_predictions  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                      Endothelial cell
# HCAHeart7606896_CGCTTCACATTTGCCC                            Mural cell
# HCAHeart7606896_GTTAAGCAGAGACTAT                      Endothelial cell
# HCAHeart7606896_TCGCGTTGTAAGAGGA                            Mural cell
# HCAHeart7606896_GCTGCGAGTGTTGGGA                      Endothelial cell
# ...                                                                ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...          Fibroblast
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...            Lymphoid
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...          Fibroblast
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...             Myeloid
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...          Mural cell
#
#                                                     leiden_scArches
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                                 10
# HCAHeart7606896_CGCTTCACATTTGCCC                                 18
# HCAHeart7606896_GTTAAGCAGAGACTAT                                 10
# HCAHeart7606896_TCGCGTTGTAAGAGGA                                  3
# HCAHeart7606896_GCTGCGAGTGTTGGGA                                 10
# ...                                                             ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...                8
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...               17
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...                1
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...               16
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...               37
#
# [704296 rows x 44 columns]

# %%
##CONCATENATING ##

# Concatenate along the observations axis (axis=0)
merged_obs = ad.concat([version1, version2], axis=0)

# Concatenate along the variables axis (axis=1)
merged_var = ad.concat([version1, version2], axis=1)

#Merging obs and var
merged_dataset = ad.concat([merged_obs,merged_var],join= 'outer')

# %%
merged_obs
# Out:
# AnnData object with n_obs × n_vars = 1190430 × 0
#     obs: 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'scrublet_score'
#     obsm: 'X_umap'

# %%
merged_var
# Out:
# AnnData object with n_obs × n_vars = 0 × 66270

# %%
merged_dataset.obs
# Out:
#                                                                     cell_type  \
# AAACCCAAGAACGCGT-1-H0015_apex                             Smooth_muscle_cells
# AAACCCAAGCAAACAT-1-H0015_apex                       Ventricular_Cardiomyocyte
# AAACCCAAGCTACTGT-1-H0015_apex                       Ventricular_Cardiomyocyte
# AAACCCAGTACCGCGT-1-H0015_apex                                       Pericytes
# AAACCCATCAAACCCA-1-H0015_apex                       Ventricular_Cardiomyocyte
# ...                                                                       ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...                 Fibroblast
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...                   Lymphoid
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...                 Fibroblast
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...                    Myeloid
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...                 Mural cell
#
#                                                    donor  gender  n_counts  \
# AAACCCAAGAACGCGT-1-H0015_apex                         H5  Female     688.0
# AAACCCAAGCAAACAT-1-H0015_apex                         H5  Female    3216.0
# AAACCCAAGCTACTGT-1-H0015_apex                         H5  Female    3182.0
# AAACCCAGTACCGCGT-1-H0015_apex                         H5  Female    1202.0
# AAACCCATCAAACCCA-1-H0015_apex                         H5  Female    3804.0
# ...                                                  ...     ...       ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...   AH2    Male     506.0
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...   AH2    Male     504.0
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...   AH2    Male     501.0
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...   AH2    Male     507.0
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...   AH2    Male     504.0
#
#                                                     n_genes region  \
# AAACCCAAGAACGCGT-1-H0015_apex                           480     AX
# AAACCCAAGCAAACAT-1-H0015_apex                          1365     AX
# AAACCCAAGCTACTGT-1-H0015_apex                          1521     AX
# AAACCCAGTACCGCGT-1-H0015_apex                           726     AX
# AAACCCATCAAACCCA-1-H0015_apex                          1584     AX
# ...                                                     ...    ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...      366    AVN
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...      433    AVN
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...      361    AVN
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...      430    AVN
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...      448    AVN
#
#                                                     scrublet_score
# AAACCCAAGAACGCGT-1-H0015_apex                             0.035917
# AAACCCAAGCAAACAT-1-H0015_apex                             0.147122
# AAACCCAAGCTACTGT-1-H0015_apex                             0.185751
# AAACCCAGTACCGCGT-1-H0015_apex                             0.035917
# AAACCCATCAAACCCA-1-H0015_apex                             0.108062
# ...                                                            ...
# HCAHeartST13180619_HCAHeartST13177116_CTTGAATCA...        0.141722
# HCAHeartST13180619_HCAHeartST13177116_AAAGCTTGT...        0.244000
# HCAHeartST13180619_HCAHeartST13177116_AATCATCCA...        0.057737
# HCAHeartST13180619_HCAHeartST13177116_AGGCTAGCA...        0.133080
# HCAHeartST13180619_HCAHeartST13177116_GCAAGTCGT...        0.266094
#
# [1190430 rows x 7 columns]

# %%
# Check for duplicate index names in observations
duplicate_obs_names = merged_dataset.obs.index[merged_dataset.obs.index.duplicated()]
print("Duplicate observation index names (cell barcodes):", duplicate_obs_names)

##As we dont have any duplicates, it is empty
# Out:
# Duplicate observation index names (cell barcodes): Index([], dtype='object')

# %%
# Check for duplicate index names in variables
duplicate_var_names = merged_dataset.var.index[merged_dataset.var.index.duplicated()]
print("Duplicate variable index names:", duplicate_var_names)

##As we dont have any duplicates, it is empty
# Out:
# Duplicate variable index names: Index([], dtype='object')
